# %%
import glob
import os
masks = sorted(glob.glob("../data/Dataset/damage_mask/Scratched_train_mask/*.png"), key=os.path.basename)
orgs = sorted(glob.glob("../data/Dataset/damage_type/Scratched_img_train/*.jpg"), key=os.path.basename)

# %%
print(len(masks))
# Out:
# 47751

# %%
# %%time

import numpy as np
import sys
from tqdm import tqdm
from PIL import Image
import cv2
# np.set_printoptions(threshold=sys.maxsize)

imgs_list2 = np.zeros((len(orgs),128,128,3), dtype=np.float32)
count = 0
masks_list = []
for image, mask in zip(tqdm(orgs), masks):
    try:
        if np.array(Image.open(image).resize((128, 128))).shape == (128,128,4):
            temp = np.delete(np.array(Image.open(image).resize((128, 128))), 3, axis=2)
            imgs_list2[count] = temp/255
        else:
            imgs_list2[count] = np.array(Image.open(image).resize((128, 128)))/255
    except ValueError:
        print("Error at", count, ValueError)
        break
#     s1 = image.split("\\")
#     s2 = mask.split("\\")

#     if not s1[1] == s2[1].replace('.png', '.jpg'):
#         print(s1[1], s2[1].replace('.png', '.jpg'))

    im = cv2.imread(mask, cv2.IMREAD_UNCHANGED)
    im = cv2.resize(im, (128,128))
    im = np.expand_dims(im, axis=-1)
    masks_list.append(im/255)
    count += 1
    
imgs_np = imgs_list2
masks_np = np.array(masks_list)
# Out:
# 100%|█████████████████████████████████████| 47751/47751 [14:33<00:00, 54.65it/s]
# CPU times: user 12min 54s, sys: 23.3 s, total: 13min 18s
# Wall time: 14min 36s

# %%
print(masks_np.shape)
# Out:
# (47751, 128, 128, 1)

# %%
# %%time

from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=imgs_np, mask_imgs=masks_np, nm_img_to_plot=10, figsize=6)
# Out:
# 2023-01-26 06:26:09.989090: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-26 06:26:12.500730: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/hyuna3589/.local/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/cuda-11.8/lib64:
# 2023-01-26 06:26:12.500884: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/hyuna3589/.local/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/cuda-11.8/lib64:
# 2023-01-26 06:26:12.500895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# CPU times: user 3.73 s, sys: 1.13 s, total: 4.86 s
# Wall time: 6.45 s

# %%
print(imgs_np.max(), masks_np.max())
# Out:
# 1.0 0.8431372549019608

# %%
x = imgs_np
y = masks_np

# %%
print(x.max(), y.max())
# Out:
# 1.0 0.8431372549019608

# %%
print(x.shape, y.shape)
# Out:
# (47751, 128, 128, 3) (47751, 128, 128, 1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.5, random_state=0)

print("x_train :", x_train.shape)
print("y_train :", y_train.shape)
print("x_val :", x_val.shape)
print("y_val :", y_val.shape)
# Out:
# x_train : (23875, 128, 128, 3)
# y_train : (23875, 128, 128, 1)
# x_val : (23876, 128, 128, 3)
# y_val : (23876, 128, 128, 1)

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    x_train, y_train, batch_size=2,
    data_gen_args=dict(
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=50,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)

from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 128, 128, 3) (2, 128, 128, 1)

# %%
from keras_unet.models import custom_unet

input_shape = x_train[0].shape

model = custom_unet(
    input_shape,
    use_batch_norm=False,
    num_classes=1,
    filters=64,
    dropout=0.2,
    output_activation='sigmoid'
)
# Out:
# 2023-01-26 06:28:50.287917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:50.782940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:50.783298: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:50.785293: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-26 06:28:50.787176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:50.787473: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:50.787660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:52.521032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:52.522724: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:52.522953: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 06:28:52.523889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14612 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0

# %%
from keras.callbacks import ModelCheckpoint

model_filename = 'segm_model_scratch.h5'
callback_checkpoint = ModelCheckpoint(
    model_filename,
    verbose=1,
    monitor='val_loss',
    save_best_only=True,
)

# %%
from tensorflow.keras.optimizers import Adam, SGD
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

model.compile(
    optimizer=SGD(lr=0.01, momentum=0.99),
    loss='binary_crossentropy',
    metrics=[iou, iou_thresholded]
)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
history=model.fit_generator(
    train_gen,
    steps_per_epoch=100,
    epochs=100,

    validation_data=(x_val,y_val),
    callbacks=[callback_checkpoint]
)
# Out:
# Epoch 1/100
# /tmp/ipykernel_4512/3335996054.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(
# 2023-01-23 06:14:15.907710: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-01-23 06:14:18.653796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2023-01-23 06:14:22.502636: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x559220729b70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-23 06:14:22.502683: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-01-23 06:14:22.875462: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 [==============================] - ETA: 0s - loss: 0.1618 - iou: 0.0080 - iou_thresholded: 0.0048
# 2023-01-23 06:14:26.847577: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 4694212608 exceeds 10% of free system memory.
# 2023-01-23 06:14:33.493549: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 4694212608 exceeds 10% of free system memory.
# Epoch 1: val_loss improved from inf to 0.09295, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 52s 413ms/step - loss: 0.1618 - iou: 0.0080 - iou_thresholded: 0.0048 - val_loss: 0.0930 - val_iou: 0.0122 - val_iou_thresholded: 1.1289e-04
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0985 - iou: 0.0115 - iou_thresholded: 0.0045
# Epoch 2: val_loss did not improve from 0.09295
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0985 - iou: 0.0115 - iou_thresholded: 0.0045 - val_loss: 0.0977 - val_iou: 0.0129 - val_iou_thresholded: 1.1289e-04
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1044 - iou: 0.0120 - iou_thresholded: 0.0035
# Epoch 3: val_loss improved from 0.09295 to 0.09236, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 288ms/step - loss: 0.1044 - iou: 0.0120 - iou_thresholded: 0.0035 - val_loss: 0.0924 - val_iou: 0.0116 - val_iou_thresholded: 1.1289e-04
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0948 - iou: 0.0112 - iou_thresholded: 0.0035
# Epoch 4: val_loss improved from 0.09236 to 0.09114, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 287ms/step - loss: 0.0948 - iou: 0.0112 - iou_thresholded: 0.0035 - val_loss: 0.0911 - val_iou: 0.0108 - val_iou_thresholded: 1.1289e-04
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0869 - iou: 0.0105 - iou_thresholded: 0.0051
# Epoch 5: val_loss improved from 0.09114 to 0.09089, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 287ms/step - loss: 0.0869 - iou: 0.0105 - iou_thresholded: 0.0051 - val_loss: 0.0909 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0881 - iou: 0.0099 - iou_thresholded: 0.0079
# Epoch 6: val_loss did not improve from 0.09089
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0881 - iou: 0.0099 - iou_thresholded: 0.0079 - val_loss: 0.0913 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0885 - iou: 0.0102 - iou_thresholded: 0.0105
# Epoch 7: val_loss improved from 0.09089 to 0.09078, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 287ms/step - loss: 0.0885 - iou: 0.0102 - iou_thresholded: 0.0105 - val_loss: 0.0908 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0863 - iou: 0.0108 - iou_thresholded: 0.0054
# Epoch 8: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0863 - iou: 0.0108 - iou_thresholded: 0.0054 - val_loss: 0.0909 - val_iou: 0.0097 - val_iou_thresholded: 1.1289e-04
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1072 - iou: 0.0121 - iou_thresholded: 0.0033
# Epoch 9: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 275ms/step - loss: 0.1072 - iou: 0.0121 - iou_thresholded: 0.0033 - val_loss: 0.0944 - val_iou: 0.0120 - val_iou_thresholded: 1.1289e-04
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0727 - iou: 0.0092 - iou_thresholded: 0.0066
# Epoch 10: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 275ms/step - loss: 0.0727 - iou: 0.0092 - iou_thresholded: 0.0066 - val_loss: 0.0939 - val_iou: 0.0067 - val_iou_thresholded: 1.1289e-04
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0953 - iou: 0.0090 - iou_thresholded: 0.0056
# Epoch 11: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 274ms/step - loss: 0.0953 - iou: 0.0090 - iou_thresholded: 0.0056 - val_loss: 0.0940 - val_iou: 0.0117 - val_iou_thresholded: 1.1289e-04
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0924 - iou: 0.0108 - iou_thresholded: 0.0060
# Epoch 12: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0924 - iou: 0.0108 - iou_thresholded: 0.0060 - val_loss: 0.0910 - val_iou: 0.0095 - val_iou_thresholded: 1.1289e-04
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0855 - iou: 0.0086 - iou_thresholded: 0.0064
# Epoch 13: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0855 - iou: 0.0086 - iou_thresholded: 0.0064 - val_loss: 0.0909 - val_iou: 0.0094 - val_iou_thresholded: 1.1289e-04
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1062 - iou: 0.0107 - iou_thresholded: 0.0040
# Epoch 14: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1062 - iou: 0.0107 - iou_thresholded: 0.0040 - val_loss: 0.0938 - val_iou: 0.0118 - val_iou_thresholded: 1.1289e-04
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0811 - iou: 0.0099 - iou_thresholded: 0.0057
# Epoch 15: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0811 - iou: 0.0099 - iou_thresholded: 0.0057 - val_loss: 0.0909 - val_iou: 0.0098 - val_iou_thresholded: 1.1289e-04
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1064 - iou: 0.0117 - iou_thresholded: 0.0043
# Epoch 16: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1064 - iou: 0.0117 - iou_thresholded: 0.0043 - val_loss: 0.0957 - val_iou: 0.0122 - val_iou_thresholded: 1.1289e-04
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0923 - iou: 0.0106 - iou_thresholded: 0.0050
# Epoch 17: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0923 - iou: 0.0106 - iou_thresholded: 0.0050 - val_loss: 0.0915 - val_iou: 0.0086 - val_iou_thresholded: 1.1289e-04
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0976 - iou: 0.0108 - iou_thresholded: 0.0041
# Epoch 18: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0976 - iou: 0.0108 - iou_thresholded: 0.0041 - val_loss: 0.0925 - val_iou: 0.0112 - val_iou_thresholded: 1.1289e-04
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0865 - iou: 0.0104 - iou_thresholded: 0.0045
# Epoch 19: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 274ms/step - loss: 0.0865 - iou: 0.0104 - iou_thresholded: 0.0045 - val_loss: 0.0908 - val_iou: 0.0098 - val_iou_thresholded: 1.1289e-04
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0848 - iou: 0.0085 - iou_thresholded: 0.0056
# Epoch 20: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0848 - iou: 0.0085 - iou_thresholded: 0.0056 - val_loss: 0.0909 - val_iou: 0.0084 - val_iou_thresholded: 1.1289e-04
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0921 - iou: 0.0101 - iou_thresholded: 0.0101
# Epoch 21: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0921 - iou: 0.0101 - iou_thresholded: 0.0101 - val_loss: 0.0925 - val_iou: 0.0112 - val_iou_thresholded: 1.1289e-04
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0868 - iou: 0.0108 - iou_thresholded: 0.0060
# Epoch 22: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0868 - iou: 0.0108 - iou_thresholded: 0.0060 - val_loss: 0.0910 - val_iou: 0.0100 - val_iou_thresholded: 1.1289e-04
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0857 - iou: 0.0099 - iou_thresholded: 0.0050
# Epoch 23: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 274ms/step - loss: 0.0857 - iou: 0.0099 - iou_thresholded: 0.0050 - val_loss: 0.0908 - val_iou: 0.0099 - val_iou_thresholded: 1.1289e-04
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0935 - iou: 0.0108 - iou_thresholded: 0.0050
# Epoch 24: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0935 - iou: 0.0108 - iou_thresholded: 0.0050 - val_loss: 0.0914 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0858 - iou: 0.0106 - iou_thresholded: 0.0064
# Epoch 25: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0858 - iou: 0.0106 - iou_thresholded: 0.0064 - val_loss: 0.0916 - val_iou: 0.0107 - val_iou_thresholded: 1.1289e-04
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0919 - iou: 0.0118 - iou_thresholded: 0.0049
# Epoch 26: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0919 - iou: 0.0118 - iou_thresholded: 0.0049 - val_loss: 0.0914 - val_iou: 0.0107 - val_iou_thresholded: 1.1289e-04
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0759 - iou: 0.0086 - iou_thresholded: 0.0073
# Epoch 27: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0759 - iou: 0.0086 - iou_thresholded: 0.0073 - val_loss: 0.0908 - val_iou: 0.0101 - val_iou_thresholded: 1.1289e-04
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0817 - iou: 0.0105 - iou_thresholded: 0.0044
# Epoch 28: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0817 - iou: 0.0105 - iou_thresholded: 0.0044 - val_loss: 0.0911 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0937 - iou: 0.0109 - iou_thresholded: 0.0049
# Epoch 29: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0937 - iou: 0.0109 - iou_thresholded: 0.0049 - val_loss: 0.0914 - val_iou: 0.0107 - val_iou_thresholded: 1.1289e-04
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0994 - iou: 0.0113 - iou_thresholded: 0.0039
# Epoch 30: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0994 - iou: 0.0113 - iou_thresholded: 0.0039 - val_loss: 0.0926 - val_iou: 0.0113 - val_iou_thresholded: 1.1289e-04
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1029 - iou: 0.0127 - iou_thresholded: 0.0045
# Epoch 31: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1029 - iou: 0.0127 - iou_thresholded: 0.0045 - val_loss: 0.0935 - val_iou: 0.0117 - val_iou_thresholded: 1.1289e-04
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0797 - iou: 0.0110 - iou_thresholded: 0.0053
# Epoch 32: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0797 - iou: 0.0110 - iou_thresholded: 0.0053 - val_loss: 0.0910 - val_iou: 0.0102 - val_iou_thresholded: 1.1289e-04
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0894 - iou: 0.0103 - iou_thresholded: 0.0064
# Epoch 33: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0894 - iou: 0.0103 - iou_thresholded: 0.0064 - val_loss: 0.0912 - val_iou: 0.0106 - val_iou_thresholded: 1.1289e-04
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0892 - iou: 0.0111 - iou_thresholded: 0.0052
# Epoch 34: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0892 - iou: 0.0111 - iou_thresholded: 0.0052 - val_loss: 0.0918 - val_iou: 0.0110 - val_iou_thresholded: 1.1289e-04
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0937 - iou: 0.0110 - iou_thresholded: 0.0044
# Epoch 35: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0937 - iou: 0.0110 - iou_thresholded: 0.0044 - val_loss: 0.0915 - val_iou: 0.0108 - val_iou_thresholded: 1.1289e-04
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0950 - iou: 0.0115 - iou_thresholded: 0.0049
# Epoch 36: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0950 - iou: 0.0115 - iou_thresholded: 0.0049 - val_loss: 0.0916 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0878 - iou: 0.0113 - iou_thresholded: 0.0066
# Epoch 37: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0878 - iou: 0.0113 - iou_thresholded: 0.0066 - val_loss: 0.0913 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0901 - iou: 0.0111 - iou_thresholded: 0.0040
# Epoch 38: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0901 - iou: 0.0111 - iou_thresholded: 0.0040 - val_loss: 0.0924 - val_iou: 0.0115 - val_iou_thresholded: 1.1289e-04
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0977 - iou: 0.0109 - iou_thresholded: 0.0043
# Epoch 39: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0977 - iou: 0.0109 - iou_thresholded: 0.0043 - val_loss: 0.0913 - val_iou: 0.0111 - val_iou_thresholded: 1.1289e-04
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0861 - iou: 0.0115 - iou_thresholded: 0.0061
# Epoch 40: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0861 - iou: 0.0115 - iou_thresholded: 0.0061 - val_loss: 0.0911 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0986 - iou: 0.0112 - iou_thresholded: 0.0040
# Epoch 41: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0986 - iou: 0.0112 - iou_thresholded: 0.0040 - val_loss: 0.0917 - val_iou: 0.0111 - val_iou_thresholded: 1.1289e-04
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0917 - iou: 0.0113 - iou_thresholded: 0.0064
# Epoch 42: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0917 - iou: 0.0113 - iou_thresholded: 0.0064 - val_loss: 0.0911 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0990 - iou: 0.0127 - iou_thresholded: 0.0042
# Epoch 43: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0990 - iou: 0.0127 - iou_thresholded: 0.0042 - val_loss: 0.0957 - val_iou: 0.0126 - val_iou_thresholded: 1.1289e-04
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0972 - iou: 0.0110 - iou_thresholded: 0.0056
# Epoch 44: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0972 - iou: 0.0110 - iou_thresholded: 0.0056 - val_loss: 0.0938 - val_iou: 0.0117 - val_iou_thresholded: 1.1289e-04
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0792 - iou: 0.0092 - iou_thresholded: 0.0054
# Epoch 45: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0792 - iou: 0.0092 - iou_thresholded: 0.0054 - val_loss: 0.0912 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0803 - iou: 0.0099 - iou_thresholded: 0.0050
# Epoch 46: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0803 - iou: 0.0099 - iou_thresholded: 0.0050 - val_loss: 0.0908 - val_iou: 0.0101 - val_iou_thresholded: 1.1289e-04
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0943 - iou: 0.0116 - iou_thresholded: 0.0046
# Epoch 47: val_loss did not improve from 0.09078
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0943 - iou: 0.0116 - iou_thresholded: 0.0046 - val_loss: 0.0912 - val_iou: 0.0110 - val_iou_thresholded: 1.1289e-04
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0796 - iou: 0.0097 - iou_thresholded: 0.0058
# Epoch 48: val_loss improved from 0.09078 to 0.09039, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 288ms/step - loss: 0.0796 - iou: 0.0097 - iou_thresholded: 0.0058 - val_loss: 0.0904 - val_iou: 0.0098 - val_iou_thresholded: 1.1289e-04
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1028 - iou: 0.0129 - iou_thresholded: 0.0040
# Epoch 49: val_loss did not improve from 0.09039
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1028 - iou: 0.0129 - iou_thresholded: 0.0040 - val_loss: 0.0931 - val_iou: 0.0121 - val_iou_thresholded: 1.1289e-04
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1037 - iou: 0.0138 - iou_thresholded: 0.0042
# Epoch 50: val_loss did not improve from 0.09039
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1037 - iou: 0.0138 - iou_thresholded: 0.0042 - val_loss: 0.0942 - val_iou: 0.0124 - val_iou_thresholded: 1.1289e-04
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0762 - iou: 0.0103 - iou_thresholded: 0.0062
# Epoch 51: val_loss improved from 0.09039 to 0.09012, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 288ms/step - loss: 0.0762 - iou: 0.0103 - iou_thresholded: 0.0062 - val_loss: 0.0901 - val_iou: 0.0101 - val_iou_thresholded: 1.1289e-04
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0837 - iou: 0.0109 - iou_thresholded: 0.0045
# Epoch 52: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0837 - iou: 0.0109 - iou_thresholded: 0.0045 - val_loss: 0.0902 - val_iou: 0.0101 - val_iou_thresholded: 1.1289e-04
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0851 - iou: 0.0101 - iou_thresholded: 0.0052
# Epoch 53: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0851 - iou: 0.0101 - iou_thresholded: 0.0052 - val_loss: 0.0909 - val_iou: 0.0110 - val_iou_thresholded: 1.1289e-04
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0869 - iou: 0.0107 - iou_thresholded: 0.0070
# Epoch 54: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0869 - iou: 0.0107 - iou_thresholded: 0.0070 - val_loss: 0.0905 - val_iou: 0.0107 - val_iou_thresholded: 1.1289e-04
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1041 - iou: 0.0113 - iou_thresholded: 0.0049
# Epoch 55: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1041 - iou: 0.0113 - iou_thresholded: 0.0049 - val_loss: 0.0932 - val_iou: 0.0118 - val_iou_thresholded: 1.1289e-04
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0914 - iou: 0.0121 - iou_thresholded: 0.0044
# Epoch 56: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0914 - iou: 0.0121 - iou_thresholded: 0.0044 - val_loss: 0.0916 - val_iou: 0.0111 - val_iou_thresholded: 1.1289e-04
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0899 - iou: 0.0102 - iou_thresholded: 0.0057
# Epoch 57: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0899 - iou: 0.0102 - iou_thresholded: 0.0057 - val_loss: 0.0907 - val_iou: 0.0096 - val_iou_thresholded: 1.1289e-04
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0970 - iou: 0.0108 - iou_thresholded: 0.0035
# Epoch 58: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0970 - iou: 0.0108 - iou_thresholded: 0.0035 - val_loss: 0.0909 - val_iou: 0.0108 - val_iou_thresholded: 1.1289e-04
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0918 - iou: 0.0113 - iou_thresholded: 0.0071
# Epoch 59: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0918 - iou: 0.0113 - iou_thresholded: 0.0071 - val_loss: 0.0914 - val_iou: 0.0111 - val_iou_thresholded: 1.1289e-04
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0999 - iou: 0.0116 - iou_thresholded: 0.0051
# Epoch 60: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0999 - iou: 0.0116 - iou_thresholded: 0.0051 - val_loss: 0.0906 - val_iou: 0.0106 - val_iou_thresholded: 1.1289e-04
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0916 - iou: 0.0113 - iou_thresholded: 0.0051
# Epoch 61: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0916 - iou: 0.0113 - iou_thresholded: 0.0051 - val_loss: 0.0913 - val_iou: 0.0113 - val_iou_thresholded: 1.1289e-04
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0909 - iou: 0.0110 - iou_thresholded: 0.0080
# Epoch 62: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0909 - iou: 0.0110 - iou_thresholded: 0.0080 - val_loss: 0.0907 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0902 - iou: 0.0108 - iou_thresholded: 0.0044
# Epoch 63: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0902 - iou: 0.0108 - iou_thresholded: 0.0044 - val_loss: 0.0910 - val_iou: 0.0112 - val_iou_thresholded: 1.1289e-04
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0978 - iou: 0.0115 - iou_thresholded: 0.0076
# Epoch 64: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0978 - iou: 0.0115 - iou_thresholded: 0.0076 - val_loss: 0.0910 - val_iou: 0.0115 - val_iou_thresholded: 1.1289e-04
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0934 - iou: 0.0111 - iou_thresholded: 0.0056
# Epoch 65: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0934 - iou: 0.0111 - iou_thresholded: 0.0056 - val_loss: 0.0907 - val_iou: 0.0112 - val_iou_thresholded: 1.1289e-04
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0909 - iou: 0.0103 - iou_thresholded: 0.0068
# Epoch 66: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0909 - iou: 0.0103 - iou_thresholded: 0.0068 - val_loss: 0.0910 - val_iou: 0.0114 - val_iou_thresholded: 1.1289e-04
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0878 - iou: 0.0112 - iou_thresholded: 0.0044
# Epoch 67: val_loss did not improve from 0.09012
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0878 - iou: 0.0112 - iou_thresholded: 0.0044 - val_loss: 0.0911 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0871 - iou: 0.0100 - iou_thresholded: 0.0049
# Epoch 68: val_loss improved from 0.09012 to 0.09002, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 289ms/step - loss: 0.0871 - iou: 0.0100 - iou_thresholded: 0.0049 - val_loss: 0.0900 - val_iou: 0.0099 - val_iou_thresholded: 1.1289e-04
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0965 - iou: 0.0111 - iou_thresholded: 0.0043
# Epoch 69: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0965 - iou: 0.0111 - iou_thresholded: 0.0043 - val_loss: 0.0911 - val_iou: 0.0112 - val_iou_thresholded: 1.1289e-04
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0882 - iou: 0.0117 - iou_thresholded: 0.0042
# Epoch 70: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0882 - iou: 0.0117 - iou_thresholded: 0.0042 - val_loss: 0.0901 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1033 - iou: 0.0115 - iou_thresholded: 0.0057
# Epoch 71: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1033 - iou: 0.0115 - iou_thresholded: 0.0057 - val_loss: 0.0938 - val_iou: 0.0122 - val_iou_thresholded: 1.1289e-04
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0915 - iou: 0.0124 - iou_thresholded: 0.0037
# Epoch 72: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0915 - iou: 0.0124 - iou_thresholded: 0.0037 - val_loss: 0.0908 - val_iou: 0.0109 - val_iou_thresholded: 1.1289e-04
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0847 - iou: 0.0104 - iou_thresholded: 0.0060
# Epoch 73: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0847 - iou: 0.0104 - iou_thresholded: 0.0060 - val_loss: 0.0901 - val_iou: 0.0104 - val_iou_thresholded: 1.1289e-04
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0839 - iou: 0.0099 - iou_thresholded: 0.0063
# Epoch 74: val_loss did not improve from 0.09002
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0839 - iou: 0.0099 - iou_thresholded: 0.0063 - val_loss: 0.0905 - val_iou: 0.0107 - val_iou_thresholded: 1.1289e-04
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0834 - iou: 0.0102 - iou_thresholded: 0.0061
# Epoch 75: val_loss improved from 0.09002 to 0.08991, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 288ms/step - loss: 0.0834 - iou: 0.0102 - iou_thresholded: 0.0061 - val_loss: 0.0899 - val_iou: 0.0105 - val_iou_thresholded: 1.1289e-04
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0914 - iou: 0.0108 - iou_thresholded: 0.0054
# Epoch 76: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0914 - iou: 0.0108 - iou_thresholded: 0.0054 - val_loss: 0.0904 - val_iou: 0.0113 - val_iou_thresholded: 1.1289e-04
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0864 - iou: 0.0115 - iou_thresholded: 0.0050
# Epoch 77: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0864 - iou: 0.0115 - iou_thresholded: 0.0050 - val_loss: 0.0912 - val_iou: 0.0116 - val_iou_thresholded: 1.1289e-04
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0879 - iou: 0.0115 - iou_thresholded: 0.0061
# Epoch 78: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0879 - iou: 0.0115 - iou_thresholded: 0.0061 - val_loss: 0.0907 - val_iou: 0.0114 - val_iou_thresholded: 1.1289e-04
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0988 - iou: 0.0131 - iou_thresholded: 0.0041
# Epoch 79: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0988 - iou: 0.0131 - iou_thresholded: 0.0041 - val_loss: 0.0903 - val_iou: 0.0117 - val_iou_thresholded: 1.1289e-04
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0863 - iou: 0.0110 - iou_thresholded: 0.0047
# Epoch 80: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0863 - iou: 0.0110 - iou_thresholded: 0.0047 - val_loss: 0.0900 - val_iou: 0.0101 - val_iou_thresholded: 1.1289e-04
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0854 - iou: 0.0096 - iou_thresholded: 0.0095
# Epoch 81: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0854 - iou: 0.0096 - iou_thresholded: 0.0095 - val_loss: 0.0902 - val_iou: 0.0113 - val_iou_thresholded: 1.1289e-04
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0956 - iou: 0.0135 - iou_thresholded: 0.0141
# Epoch 82: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0956 - iou: 0.0135 - iou_thresholded: 0.0141 - val_loss: 0.0934 - val_iou: 0.0128 - val_iou_thresholded: 1.1289e-04
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0981 - iou: 0.0134 - iou_thresholded: 0.0037
# Epoch 83: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0981 - iou: 0.0134 - iou_thresholded: 0.0037 - val_loss: 0.0903 - val_iou: 0.0116 - val_iou_thresholded: 1.1289e-04
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0904 - iou: 0.0122 - iou_thresholded: 0.0051
# Epoch 84: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0904 - iou: 0.0122 - iou_thresholded: 0.0051 - val_loss: 0.0915 - val_iou: 0.0126 - val_iou_thresholded: 1.1289e-04
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0855 - iou: 0.0126 - iou_thresholded: 0.0040
# Epoch 85: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0855 - iou: 0.0126 - iou_thresholded: 0.0040 - val_loss: 0.0900 - val_iou: 0.0124 - val_iou_thresholded: 1.1289e-04
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0800 - iou: 0.0124 - iou_thresholded: 0.0048
# Epoch 86: val_loss did not improve from 0.08991
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0800 - iou: 0.0124 - iou_thresholded: 0.0048 - val_loss: 0.0913 - val_iou: 0.0131 - val_iou_thresholded: 1.1289e-04
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0936 - iou: 0.0137 - iou_thresholded: 0.0051
# Epoch 87: val_loss improved from 0.08991 to 0.08955, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 288ms/step - loss: 0.0936 - iou: 0.0137 - iou_thresholded: 0.0051 - val_loss: 0.0896 - val_iou: 0.0135 - val_iou_thresholded: 1.1289e-04
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0854 - iou: 0.0131 - iou_thresholded: 0.0067
# Epoch 88: val_loss improved from 0.08955 to 0.08925, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 288ms/step - loss: 0.0854 - iou: 0.0131 - iou_thresholded: 0.0067 - val_loss: 0.0892 - val_iou: 0.0095 - val_iou_thresholded: 1.1289e-04
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0904 - iou: 0.0136 - iou_thresholded: 0.0092
# Epoch 89: val_loss did not improve from 0.08925
# 100/100 [==============================] - 27s 273ms/step - loss: 0.0904 - iou: 0.0136 - iou_thresholded: 0.0092 - val_loss: 0.0904 - val_iou: 0.0133 - val_iou_thresholded: 1.1289e-04
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0993 - iou: 0.0141 - iou_thresholded: 0.0042
# Epoch 90: val_loss did not improve from 0.08925
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0993 - iou: 0.0141 - iou_thresholded: 0.0042 - val_loss: 0.0903 - val_iou: 0.0132 - val_iou_thresholded: 1.1289e-04
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0871 - iou: 0.0137 - iou_thresholded: 0.0037
# Epoch 91: val_loss improved from 0.08925 to 0.08840, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 288ms/step - loss: 0.0871 - iou: 0.0137 - iou_thresholded: 0.0037 - val_loss: 0.0884 - val_iou: 0.0136 - val_iou_thresholded: 1.1289e-04
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0972 - iou: 0.0144 - iou_thresholded: 0.0045
# Epoch 92: val_loss did not improve from 0.08840
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0972 - iou: 0.0144 - iou_thresholded: 0.0045 - val_loss: 0.0888 - val_iou: 0.0137 - val_iou_thresholded: 1.1289e-04
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1024 - iou: 0.0137 - iou_thresholded: 0.0068
# Epoch 93: val_loss did not improve from 0.08840
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1024 - iou: 0.0137 - iou_thresholded: 0.0068 - val_loss: 0.0914 - val_iou: 0.0141 - val_iou_thresholded: 1.1289e-04
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0802 - iou: 0.0121 - iou_thresholded: 0.0049
# Epoch 94: val_loss did not improve from 0.08840
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0802 - iou: 0.0121 - iou_thresholded: 0.0049 - val_loss: 0.0897 - val_iou: 0.0097 - val_iou_thresholded: 1.1289e-04
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0936 - iou: 0.0127 - iou_thresholded: 0.0064
# Epoch 95: val_loss did not improve from 0.08840
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0936 - iou: 0.0127 - iou_thresholded: 0.0064 - val_loss: 0.0908 - val_iou: 0.0131 - val_iou_thresholded: 1.1289e-04
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0903 - iou: 0.0131 - iou_thresholded: 0.0054
# Epoch 96: val_loss improved from 0.08840 to 0.08733, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 28s 287ms/step - loss: 0.0903 - iou: 0.0131 - iou_thresholded: 0.0054 - val_loss: 0.0873 - val_iou: 0.0123 - val_iou_thresholded: 1.1289e-04
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0881 - iou: 0.0132 - iou_thresholded: 0.0049
# Epoch 97: val_loss did not improve from 0.08733
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0881 - iou: 0.0132 - iou_thresholded: 0.0049 - val_loss: 0.0881 - val_iou: 0.0128 - val_iou_thresholded: 1.1289e-04
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0833 - iou: 0.0118 - iou_thresholded: 0.0042
# Epoch 98: val_loss did not improve from 0.08733
# 100/100 [==============================] - 27s 271ms/step - loss: 0.0833 - iou: 0.0118 - iou_thresholded: 0.0042 - val_loss: 0.0873 - val_iou: 0.0129 - val_iou_thresholded: 1.1289e-04
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0928 - iou: 0.0134 - iou_thresholded: 0.0142
# Epoch 99: val_loss did not improve from 0.08733
# 100/100 [==============================] - 27s 272ms/step - loss: 0.0928 - iou: 0.0134 - iou_thresholded: 0.0142 - val_loss: 0.0883 - val_iou: 0.0138 - val_iou_thresholded: 1.1289e-04
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0847 - iou: 0.0129 - iou_thresholded: 0.0062
# Epoch 100: val_loss improved from 0.08733 to 0.08727, saving model to segm_model_scratch.h5
# 100/100 [==============================] - 29s 289ms/step - loss: 0.0847 - iou: 0.0129 - iou_thresholded: 0.0062 - val_loss: 0.0873 - val_iou: 0.0137 - val_iou_thresholded: 1.1289e-04

# %%
import glob
tests = glob.glob("../data/Dataset/damage_type/Scratched_img_test/*.jpg")

# %%
import numpy as np
from PIL import Image
import cv2

tests_list=[]
for test in tests:
    test_img = cv2.imread(test)
    # print(im.shape)
    test_img = cv2.resize(test_img, (128,128))
    # print(im.shape)

    #print(im.shape)
    tests_list.append(test_img)

tests_np = np.asarray(tests_list)

# %%
tests_np.shape
# Out:
# (5975, 128, 128, 3)

# %%
model.load_weights('segm_model_scratch.h5')

test_preds = model.predict(tests_np)
# test_preds
# Out:
# 187/187 [==============================] - 6s 30ms/step

# %%
print(test_preds.shape)

test = np.zeros((len(test_preds), 128, 128, 1))

for t in tqdm(range(len(test_preds))):
    ret, dst = cv2.threshold(test_preds[t], np.percentile((test_preds[t]*255), 55), 255, cv2.THRESH_BINARY)
    test[t] = np.expand_dims(dst, axis=-1)
    
print(test.shape)
# Out:
# (5975, 128, 128, 1)
# 100%|█████████████████████████████████████| 5975/5975 [00:02<00:00, 2196.64it/s]
# (5975, 128, 128, 1)

# %%
import matplotlib.pyplot as plt

plt.imshow(test[0])

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=tests_np, mask_imgs=test, nm_img_to_plot=5, figsize=6)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /usr/lib/python3/dist-packages (22.0.2)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (59.6.0)
# Collecting setuptools
#   Downloading setuptools-66.1.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (0.37.1)
# Collecting wheel
#   Downloading wheel-0.38.4-py3-none-any.whl (36 kB)
# Installing collected packages: wheel, setuptools, pip
#   WARNING: The script wheel is installed in '/home/hyuna3589/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pip, pip3 and pip3.10 are installed in '/home/hyuna3589/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-22.3.1 setuptools-66.1.1 wheel-0.38.4

# %%
# !pip install keras-unet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras-unet
#   Downloading keras_unet-0.1.2-py3-none-any.whl (16 kB)
# Installing collected packages: keras-unet
# Successfully installed keras-unet-0.1.2

# %%
# !pip install keras-unet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-unet in /home/hyuna3589/.local/lib/python3.10/site-packages (0.1.2)

# %%
#!pip install matplotlib
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /home/hyuna3589/.local/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.24.1)
